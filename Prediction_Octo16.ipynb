# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Amazon_Laptop_Prices.csv')

# %%
df.dtypes
# Out:
# Laptop Name           object
# Laptop Weight        float64
# Ram Size               int64
# Hard Drive Size        int64
# Processor Speed      float64
# Processor Type        object
# Screen Size          float64
# Operating System      object
# Memory Technology     object
# Price                float64
# dtype: object

# %%
df[(df['Ram Size'] < 9).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-0bd0a2a49151> in <module>
#       1
# ----> 2 df[(df['Ram Size'] < 9).all(axis=1)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in logical_func(self, axis, bool_only, skipna, level, **kwargs)
#   11030                                       skipna=skipna)
#   11031         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 11032                             numeric_only=bool_only, filter_type='bool')
#   11033
#   11034     return set_function_name(logical_func, name, cls)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3609
#    3610         if axis is not None:
# -> 3611             self._get_axis_number(axis)
#    3612
#    3613         if isinstance(delegate, Categorical):
#
# ...

# %%
import seaborn as sns
sns.boxplot(x=df['Price'])

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Price'], df['Ram Size'])
ax.set_xlabel('Proportion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()

# %%
df['Laptop Name'].unique()
# Out:
# array(['HP', 'Lenovo', 'LENOVO', 'Dell', 'Asus'], dtype=object)

# %%
lp_repl_val = {'Lenovo':'Lenovo','LENOVO':'Lenovo','HP':'HP','Dell':'Dell','Asus':'Asus'}
df['Laptop Name']= df['Laptop Name'].map(lp_repl_val)

# %%
Laptop_replace_values = {'HP':0, 'Lenovo':1, 'Dell':2, 'Asus':3}
df['Laptop Name'] = df['Laptop Name'].map(Laptop_replace_values)

# %%
df.head()
# Out:
#    Laptop Name  Laptop Weight  Ram Size  Hard Drive Size  Processor Speed  \
# 0            0           2.04         4             1024              2.4
# 1            0            NaN         8             1024              3.9
# 2            0           2.76         4             1024              1.6
# 3            0           2.04         8             1024              3.4
# 4            0           1.59         4             1024              2.1
#
#   Processor Type  Screen Size Operating System Memory Technology    Price
# 0  Core i3 7100U         15.6  Windows 10 Home             GDDR4  30290.0
# 1        Core i5         14.0  Windows 10 Home        DDR4 SDRAM  46861.0
# 2        Core i5         15.6       Windows 10         DDR SDRAM  42094.0
# 3  Core i5 8250U         15.6              DOS             GDDR5  43998.0
# 4        Core i3         14.0  Windows 10 Home              DDR4  49289.0

# %%
df['Processor Type'].unique()
# Out:
# array(['Core i3 7100U', 'Core i5', 'Core i5 8250U', 'Core i3',
#        'Core i5 7200U', 'Core i3 8130U', 'Core i5 6200U', 'Core i3-5005U',
#        'Core i7', 'Core i5 8300H', 'Core i5 8400T'], dtype=object)

# %%
processor_type_replace_values = {'Core i3 7100U':0, 'Core i5':1, 'Core i5 8250U':2, 'Core i3':3,
       'Core i5 7200U':4, 'Core i3 8130U':5, 'Core i5 6200U':6, 'Core i3-5005U':7,
       'Core i7':8, 'Core i5 8300H':9, 'Core i5 8400T':10}
df['Processor Type'] = df['Processor Type'].map(processor_type_replace_values)

# %%
df['Operating System'].unique()
# Out:
# array(['Windows 10 Home', 'Windows 10', 'DOS',
#        'Windows 10 Home Single Language 64', 'windows 10',
#        'windows 10 pro', 'Windows 10 Pro', 'Windows 10 With Office 2016',
#        'Linux', 'Windows 10 With Office 2019', 'Windows 10 Professional',
#        'windows 10 Home', 'Win 10', 'Windows 10 with Office 2016'],
#       dtype=object)

# %%
replace_values = {'Windows 10 Home':'Windows 10 Home', 'Windows 10':'Windows 10', 'DOS':'DOS',
       'Windows 10 Home Single Language 64':'Windows 10 Home', 'windows 10':'Windows 10',
       'windows 10 pro':'Windows 10 Professional', 'Windows 10 Pro':'Windows 10 Professional',
        'Windows 10 With Office 2016':'Windows 10 With Office 2016',
       'Linux':'Linux', 'Windows 10 With Office 2019':'Windows 10 With Office 2019', 'Windows 10 Professional':'Windows 10 Professional',
       'windows 10 Home':'Windows 10 Home', 'Win 10':'Windows 10', 'Windows 10 with Office 2016':'Windows 10 With Office 2016'}
df['Operating System'] = df['Operating System'].map(replace_values)

# %%
os_rplace_values = {'Windows 10 Home':0, 'Windows 10':1, 'DOS':2, 'Windows 10 Professional':3,
       'Windows 10 With Office 2016':4, 'Linux':5,
       'Windows 10 With Office 2019':5}
df['Operating System'] = df['Operating System'].map(os_rplace_values)

# %%
df['Memory Technology'].unique()
# Out:
# array(['GDDR4', 'DDR4 SDRAM', 'DDR SDRAM', 'GDDR5', 'DDR4', 'GDDR3',
#        'DDR3 SDRAM', 'DDR3', 'DDR4, Optane', 'SDRAM', 'DDR3L', 'SODIMM'],
#       dtype=object)

# %%
mem_tech_replace_values = {'GDDR4':0, 'DDR4 SDRAM':1, 'DDR SDRAM':2, 'GDDR5':3, 'DDR4':4, 'GDDR3':5,
       'DDR3 SDRAM':6, 'DDR3':7, 'DDR4, Optane':8, 'SDRAM':9, 'DDR3L':10, 'SODIMM':11}
df['Memory Technology'] = df['Memory Technology'].map(mem_tech_replace_values)

# %%
df.isnull().sum()
# Out:
# Laptop Name          0
# Laptop Weight        3
# Ram Size             0
# Hard Drive Size      0
# Processor Speed      0
# Processor Type       0
# Screen Size          0
# Operating System     0
# Memory Technology    0
# Price                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# Laptop Name            int64
# Laptop Weight        float64
# Ram Size               int64
# Hard Drive Size        int64
# Processor Speed      float64
# Processor Type         int64
# Screen Size          float64
# Operating System       int64
# Memory Technology      int64
# Price                float64
# dtype: object

# %%
df.corr()
# Out:
#                    Laptop Name  Laptop Weight  Ram Size  Hard Drive Size  \
# Laptop Name           1.000000       0.223829  0.171053         0.000777
# Laptop Weight         0.223829       1.000000  0.028590         0.067355
# Ram Size              0.171053       0.028590  1.000000         0.132514
# Hard Drive Size       0.000777       0.067355  0.132514         1.000000
# Processor Speed       0.026649      -0.041570  0.230192        -0.046005
# Processor Type        0.123663       0.095917  0.126618         0.008804
# Screen Size           0.088819       0.337927  0.207342        -0.001624
# Operating System      0.280133       0.279801  0.066647         0.009452
# Memory Technology    -0.194954      -0.100814 -0.047951        -0.071578
# Price                 0.021353       0.057962  0.473304         0.002654
#
#                    Processor Speed  Processor Type  Screen Size  \
# Laptop Name               0.026649        0.123663     0.088819
# ...

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
print(z)
# Out:
# [[1.35454006 0.22421165 0.92217222 ... 0.85759103 1.4388142  1.46602904]
#  [1.35454006 0.84931372 0.92217222 ... 0.02503915 0.49381524 0.35140257]
#  [1.35454006 0.22421165 0.67067071 ... 0.80751273 0.02131577 0.17161192]
#  ...
#  [2.06610224 0.32858217 0.67067071 ... 0.02503915 0.96631472 0.78560331]
#  [2.06610224 0.76097433 0.67067071 ... 0.02503915 0.45118371 0.99813899]
#  [2.06610224 1.02935568 0.92217222 ... 0.02503915 0.96631472 1.11664596]]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([ 40,  53,  65,  68,  70,  80,  82,  82,  88,  88,  89,  90,  99,
#         99, 106, 110, 112, 116, 117, 120, 124, 125]), array([3, 3, 3, 3, 8, 8, 1, 6, 5, 7, 7, 7, 2, 3, 8, 2, 3, 3, 1, 7, 3, 3]))

# %%
from scipy import stats
df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

# %%
df
# Out:
#      Laptop Name  Laptop Weight  Ram Size  Hard Drive Size  Processor Speed  \
# 0              0           2.04         4             1024              2.4
# 2              0           2.76         4             1024              1.6
# 3              0           2.04         8             1024              3.4
# 4              0           1.59         4             1024              2.1
# 5              0           2.04         4             1024              3.1
# 6              0           1.47         4             1024              2.3
# 7              0           2.04         8             1024              2.3
# 8              0           2.25         8             1024              2.4
# 9              0           1.77         8             1024              1.6
# 10             0           2.04         8             1024              3.4
# 11             0           1.86         4             1024              2.5
# ...

# %%
df['Price'] = np.log1p(df['Price'])

# %%
from scipy.stats import norm
sns.distplot(df['Price'], fit=norm )

# %%
X = df.iloc[:,[0,1,2,3,4,5,6,7,8]]
y = df.iloc[:,-1]

# %%
np.expm1(df['Price'].mean())
# Out:
# 2.4577271984681377

# %%
np.expm1(df['Price'].mode())
# Out:
# 0    2.436578
# 1    2.452823
# dtype: float64

# %%
np.expm1(df['Price'].median())
# Out:
# 2.4557087903299397

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2,
           oob_score=False, random_state=5, verbose=0, warm_start=False)

# %%
clf.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2,
#            oob_score=False, random_state=5, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X)
np.expm1(y_pred)
# Out:
# array([2.43971684, 2.45217043, 2.46154228, 2.46875488, 2.45237509,
#        2.43812066, 2.44911788, 2.48519181, 2.46729438, 2.4665582 ,
#        2.44482469, 2.45449582, 2.45940169, 2.45329718, 2.4827996 ,
#        2.46875488, 2.45253394, 2.45612034, 2.45411247, 2.47551688,
#        2.44594281, 2.45299469, 2.47372345, 2.44415548, 2.48495295,
#        2.46232147, 2.44987704, 2.4665582 , 2.44600705, 2.49460468,
#        2.45504037, 2.4800454 , 2.48168689, 2.48258014, 2.45940423,
#        2.42780009, 2.44061769, 2.45940423, 2.43354576, 2.44396516,
#        2.44301049, 2.44670609, 2.43714097, 2.45363654, 2.46420781,
#        2.45905048, 2.47027396, 2.46836271, 2.4605784 , 2.44521765,
#        2.42739106, 2.43462895, 2.43741928, 2.45273107, 2.43258504,
#        2.43492705, 2.44686373, 2.43608511, 2.4635188 , 2.43900258,
#        2.48726788, 2.44101726, 2.44175075, 2.47579226, 2.4729918 ,
#        2.46693777, 2.48932399, 2.43211398, 2.45473339, 2.45546466,
# ...

# %%
y_pred = clf.predict([[0,2.04,8,1024,2.4,0,15.6,0,0]])
np.expm1(y_pred)
# Out:
# array([2.44414496])

# %%
from sklearn import metrics
print('r2 value                : ', metrics.r2_score(y, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-3c7c5d0ad7aa> in <module>
#       1 from sklearn import metrics
# ----> 2 print('r2 value                : ', metrics.r2_score(y, y_pred))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     532     """
#     533     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 534         y_true, y_pred, multioutput)
#     535     check_consistent_length(y_true, y_pred, sample_weight)
#     536
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ...
